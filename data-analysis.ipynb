# %% [markdown]
# # Análise de Dados
#
# **Tema:** CyberSecurity
# **Fonte:** [CyberSecurity - Kaggle](https://www.kaggle.com/datasets/atharvasoundankar/global-cybersecurity-threats-2015-2024)

# %% [markdown]
# ---
#
# ### Importação de Pacotes Necessários
#
# ---

# %%
import pandas as pd

# %% [markdown]
# ### Armazenando o Dataset em uma Variável

# %%
dados = pd.read_csv('dataset/Global_Cybersecurity_Threats_2015-2024.csv')

# %% [markdown]
# ### Análise Exploratória

# %%
# Tamanho do Dataframe
dados.shape
print(f'O dataset possui {dados.shape[0]} registros (linhas) e {dados.shape[1]} atributos (colunas)')
# Out:
# O dataset possui 3000 registros (linhas) e 10 atributos (colunas)

# %%
# Verificando os primeiros registros do dataset
dados.head (10)
# Out:
#       País   Ano     Tipo de Ataque      Indústria Alvo  \
# 0    China  2019           Phishing           Education
# 1    China  2019         Ransomware              Retail
# 2    India  2017  Man-in-the-Middle                  IT
# 3       UK  2024         Ransomware  Telecommunications
# 4  Germany  2018  Man-in-the-Middle                  IT
# 5  Germany  2017  Man-in-the-Middle              Retail
# 6  Germany  2016               DDoS  Telecommunications
# 7   France  2018      SQL Injection          Government
# 8    India  2016  Man-in-the-Middle             Banking
# 9       UK  2023               DDoS          Healthcare
#
#    Prejuízo Financeiro (em Milhões de $)  Número de Usuários Afetados  \
# 0                                  80.53                       773169
# 1                                  62.19                       295961
# 2                                  38.65                       605895
# ...

# %%
# Traduzindo o conteúdo do dataset através de um dicionário

traducao_colunas = {
    "Country": "País",
    "Year": "Ano",
    "Attack Type": "Tipo de Ataque",
    "Target Industry": "Indústria Alvo",
    "Financial Loss (in Million $)": "Prejuízo Financeiro (em Milhões de $)",
    "Number of Affected Users": "Número de Usuários Afetados",
    "Attack Source": "Fonte do Ataque",
    "Security Vulnerability Type": "Tipo de Vulnerabilidade de Segurança",
    "Defense Mechanism Used": "Mecanismo de Defesa Utilizado",
    "Incident Resolution Time (in Hours)": "Tempo de Resolução do Incidente (em Horas)"
}

# %%
# Renomeando as colunas com base no dicionário criado

dados.rename(columns=traducao_colunas, inplace=True)

# %%
# Verificando novamente os primerios registro do dataset

dados.head(10)
# Out:
#       País   Ano     Tipo de Ataque      Indústria Alvo  \
# 0    China  2019           Phishing           Education
# 1    China  2019         Ransomware              Retail
# 2    India  2017  Man-in-the-Middle                  IT
# 3       UK  2024         Ransomware  Telecommunications
# 4  Germany  2018  Man-in-the-Middle                  IT
# 5  Germany  2017  Man-in-the-Middle              Retail
# 6  Germany  2016               DDoS  Telecommunications
# 7   France  2018      SQL Injection          Government
# 8    India  2016  Man-in-the-Middle             Banking
# 9       UK  2023               DDoS          Healthcare
#
#    Prejuízo Financeiro (em Milhões de $)  Número de Usuários Afetados  \
# 0                                  80.53                       773169
# 1                                  62.19                       295961
# 2                                  38.65                       605895
# ...

# %%
# Verificando os tipos de dados de cada coluna
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 10 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   País                                        3000 non-null   object
#  1   Ano                                         3000 non-null   int64
#  2   Tipo de Ataque                              3000 non-null   object
#  3   Indústria Alvo                              3000 non-null   object
#  4   Prejuízo Financeiro (em Milhões de $)       3000 non-null   float64
#  5   Número de Usuários Afetados                 3000 non-null   int64
#  6   Fonte do Ataque                             3000 non-null   object
#  7   Tipo de Vulnerabilidade de Segurança        3000 non-null   object
#  8   Mecanismo de Defesa Utilizado               3000 non-null   object
#  9   Tempo de Resolução do Incidente (em Horas)  3000 non-null   int64
# ...

# %%
# Estatísticas descritivas das colunas com dados numéricos
dados.describe()
# Out:
#                Ano  Prejuízo Financeiro (em Milhões de $)  \
# count  3000.000000                            3000.000000
# mean   2019.570333                              50.492970
# std       2.857932                              28.791415
# min    2015.000000                               0.500000
# 25%    2017.000000                              25.757500
# 50%    2020.000000                              50.795000
# 75%    2022.000000                              75.630000
# max    2024.000000                              99.990000
#
#        Número de Usuários Afetados  Tempo de Resolução do Incidente (em Horas)
# count                  3000.000000                                 3000.000000
# mean                 504684.136333                                   36.476000
# std                  289944.084972                                   20.570768
# min                     424.000000                                    1.000000
# ...

# %%
# Descobrindo o maior prejuízo financeiro e em qual país/ano aconteceu
maior_prejuizo = dados['Prejuízo Financeiro (em Milhões de $)'].max()
dados_completos = dados[dados['Prejuízo Financeiro (em Milhões de $)'] == maior_prejuizo]
print(dados_completos.to_string())
# Out:
#            País   Ano Tipo de Ataque Indústria Alvo  Prejuízo Financeiro (em Milhões de $)  Número de Usuários Afetados Fonte do Ataque Tipo de Vulnerabilidade de Segurança Mecanismo de Defesa Utilizado  Tempo de Resolução do Incidente (em Horas)
# 1806  Australia  2017  SQL Injection             IT                                  99.99                       672966    Hacker Group                             Zero-day                      Firewall                                          13
# 2030      China  2024           DDoS        Banking                                  99.99                       755185         Unknown                       Weak Passwords                    Encryption                                          20

# %%
# Melhorando a visualização anterior 
print(dados_completos.iloc[0])
# Out:
# País                                              Australia
# Ano                                                    2017
# Tipo de Ataque                                SQL Injection
# Indústria Alvo                                           IT
# Prejuízo Financeiro (em Milhões de $)                 99.99
# Número de Usuários Afetados                          672966
# Fonte do Ataque                                Hacker Group
# Tipo de Vulnerabilidade de Segurança               Zero-day
# Mecanismo de Defesa Utilizado                      Firewall
# Tempo de Resolução do Incidente (em Horas)               13
# Name: 1806, dtype: object

# %%
dados['Tipo de Ataque'].value_counts()
# Out:
# Tipo de Ataque
# DDoS                 531
# Phishing             529
# SQL Injection        503
# Ransomware           493
# Malware              485
# Man-in-the-Middle    459
# Name: count, dtype: int64
